# %%
! python3 -m pip install pymongo[srv]
! python3 -m pip install psycopg2-binary

import pymongo
import dns
import time
from bson.objectid import ObjectId
from bson.json_util import dumps

client = pymongo.MongoClient(conString)
# Out:
# Requirement already satisfied: pymongo[srv] in /usr/local/lib/python3.7/dist-packages (4.1.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from pymongo[srv]) (2.2.1)
# Requirement already satisfied: psycopg2-binary in /usr/local/lib/python3.7/dist-packages (2.9.3)

# %%
import psycopg2
import urllib.parse as up
url = up.urlparse(SQLconString)
conn = psycopg2.connect(database=url.path[1:], user=url.username, password=url.password, host=url.hostname, port=url.port )

# %% [markdown]
# Users Stream pass

# %%
def stringTransform(stringName):
  try:
    data = str((change['fullDocument'][stringName]))
    data = data.replace("'", "")
    data = data.replace('"', '')
    data = "".join(("'",data,"'"))
  except KeyError:
    data = "NULL"  
  except Exception as e:
    print(e + " e exception")
  return data

db = client[client.list_database_names()[0]]
collection = db['users']
change_stream = collection.watch()
conn = psycopg2.connect(database=url.path[1:], user=url.username, password=url.password, host=url.hostname, port=url.port )
cur_esq = conn.cursor()

for change in change_stream:
    if(change['operationType'] == 'insert'):
        insertString = ""

        userID = stringTransform('_id')
        firstName = stringTransform('firstName')
        lastName = stringTransform('lastName') 
        email = stringTransform('email') 
        birthday = stringTransform('birthday')
        epigraph = stringTransform('epigraph')
        createdAt = stringTransform('createdAt')
        updatedAt = stringTransform('updatedAt')

        insertString = "".join((insertString,"".join(("(", ",".join((userID, epigraph, birthday, email, firstName, lastName, createdAt, updatedAt)),")"))))
        cur_esq.execute("".join(("insert into users (userid, epigraph, birthday, email, firstname, lastname, createat, updatedat) Values", insertString)))

        conn.commit()
cur_esq.close()
conn.close()

# %% [markdown]
# Circle Stream pass

# %%
def stringTransform(stringName):
  try:
    data = str((change['fullDocument'][stringName]))
    data = data.replace("'", "")
    data = data.replace('"', '')
    data = "".join(("'",data,"'"))
  except KeyError:
    data = "NULL"  
  except Exception as e:
    print(e + " e exception")
  return data

db = client[client.list_database_names()[0]]
collection = db['circles']

change_stream = collection.watch()
conn = psycopg2.connect(database=url.path[1:], user=url.username, password=url.password, host=url.hostname, port=url.port )
cur_esq = conn.cursor()

for change in change_stream:
    if(change['operationType'] == 'insert'):
        insertString = ""

        circleID = stringTransform('_id')
        circleName = stringTransform('name')
        Type = stringTransform('type')
        createdAt = stringTransform('createdAt')
        updatedAt = stringTransform('updatedAt')

        insertString = "".join((insertString,"".join(("(", ",".join((circleID, circleName, Type, createdAt, updatedAt)),")"))))
        cur_esq.execute("".join(("insert into circle (CircleID, CircleName, Type, CreateAt, UpdatedAt) values", insertString)))
        conn.commit()
cur_esq.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-6e1ffc8f26c3> in <module>()
#      18 cur_esq = conn.cursor()
#      19
# ---> 20 for change in change_stream:
#      21     if(change['operationType'] == 'insert'):
#      22         insertString = ""
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in next(self)
#     278         """
#     279         while self.alive:
# --> 280             doc = self.try_next()
#     281             if doc is not None:
#     282                 return doc
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in try_next(self)
#     332         # one resume attempt.
#     333         try:
# --> 334             change = self._cursor._try_next(True)
#     335         except (ConnectionFailure, CursorNotFound):
#     336             self._resume()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _try_next(self, get_more_allowed)
#     293         """Advance the cursor blocking for at most one getMore command."""
#     294         if not len(self.__data) and not self.__killed and get_more_allowed:
# --> 295             self._refresh()
#     296         if len(self.__data):
#     297             return self.__data.popleft()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _refresh(self)
#     227                     self.__sock_mgr,
#     228                     False,
# --> 229                     self.__comment,
#     230                 )
#     231             )
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in __send_message(self, operation)
#     161         try:
#     162             response = client._run_operation(
# --> 163                 operation, self._unpack_response, address=self.__address
#     164             )
#     165         except OperationFailure as exc:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1270             operation.session,
#    1271             address=address,
# -> 1272             retryable=isinstance(operation, message._Query),
#    1273         )
#    1274
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable)
#    1369                         assert last_error is not None
#    1370                         raise last_error
# -> 1371                     return func(session, server, sock_info, read_pref)
#    1372             except ServerSelectionTimeoutError:
#    1373                 if retrying:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _cmd(session, server, sock_info, read_preference)
#    1262         def _cmd(session, server, sock_info, read_preference):
#    1263             return server.run_operation(
# -> 1264                 sock_info, operation, read_preference, self._event_listeners, unpack_res
#    1265             )
#    1266
#
# /usr/local/lib/python3.7/dist-packages/pymongo/server.py in run_operation(self, sock_info, operation, read_preference, listeners, unpack_res)
#     113             else:
#     114                 sock_info.send_message(data, max_doc_size)
# --> 115                 reply = sock_info.receive_message(request_id)
#     116
#     117             # Unpack and check for command errors.
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
# --> 796             self._raise_connection_failure(error)
#     797
#     798     def _raise_if_not_writable(self, unacknowledged):
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     792         """
#     793         try:
# --> 794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
#     796             self._raise_connection_failure(error)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in receive_message(sock_info, request_id, max_message_size)
#     206     # Ignore the response's request id.
#     207     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 208         _receive_data_on_socket(sock_info, 16, deadline)
#     209     )
#     210     # No request_id for exhaust cursor "getMore".
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in _receive_data_on_socket(sock_info, length, deadline)
#     279         try:
#     280             wait_for_read(sock_info, deadline)
# --> 281             chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     282         except (IOError, OSError) as exc:  # noqa: B014
#     283             if _errno_from_exception(exc) == errno.EINTR:
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# Chapter Stream pass

# %%
def stringTransform(stringName):
  try:
    data = str((change['fullDocument'][stringName]))
    data = data.replace("'", "")
    data = data.replace('"', '')
    data = "".join(("'",data,"'"))
  except KeyError:
    data = "NULL"  
  except Exception as e:
    print(e + " e exception")
  return data

db = client[client.list_database_names()[0]]
collection = db['chapters']
change_stream = collection.watch()
conn = psycopg2.connect(database=url.path[1:], user=url.username, password=url.password, host=url.hostname, port=url.port )
cur_esq = conn.cursor()

for change in change_stream:
    if(change['operationType'] == 'insert'):
        insertString = ""

        chapterID = stringTransform('_id')
        circleID = stringTransform('circle')
        creatorID = stringTransform('creator') 
        locationID = stringTransform('location') 
        chapterName = stringTransform('name')
        isCollaborative = stringTransform('isCollaborative')
        createdAt = stringTransform('createdAt')
        updatedAt = stringTransform('updatedAt')

        insertString = "".join((insertString,"".join(("(", ",".join((chapterID, circleID, creatorID, chapterName, isCollaborative, createdAt, updatedAt)),")"))))
        cur_esq.execute("".join(("insert into chapter (chapterID, circleID, creatorID, chapterName, isCollaborative, createAt, updatedAt) values", insertString)))

        conn.commit()
cur_esq.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3bdd53ce1b46> in <module>()
#      17 cur_esq = conn.cursor()
#      18
# ---> 19 for change in change_stream:
#      20     if(change['operationType'] == 'insert'):
#      21         insertString = ""
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in next(self)
#     278         """
#     279         while self.alive:
# --> 280             doc = self.try_next()
#     281             if doc is not None:
#     282                 return doc
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in try_next(self)
#     332         # one resume attempt.
#     333         try:
# --> 334             change = self._cursor._try_next(True)
#     335         except (ConnectionFailure, CursorNotFound):
#     336             self._resume()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _try_next(self, get_more_allowed)
#     293         """Advance the cursor blocking for at most one getMore command."""
#     294         if not len(self.__data) and not self.__killed and get_more_allowed:
# --> 295             self._refresh()
#     296         if len(self.__data):
#     297             return self.__data.popleft()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _refresh(self)
#     227                     self.__sock_mgr,
#     228                     False,
# --> 229                     self.__comment,
#     230                 )
#     231             )
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in __send_message(self, operation)
#     161         try:
#     162             response = client._run_operation(
# --> 163                 operation, self._unpack_response, address=self.__address
#     164             )
#     165         except OperationFailure as exc:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1270             operation.session,
#    1271             address=address,
# -> 1272             retryable=isinstance(operation, message._Query),
#    1273         )
#    1274
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable)
#    1369                         assert last_error is not None
#    1370                         raise last_error
# -> 1371                     return func(session, server, sock_info, read_pref)
#    1372             except ServerSelectionTimeoutError:
#    1373                 if retrying:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _cmd(session, server, sock_info, read_preference)
#    1262         def _cmd(session, server, sock_info, read_preference):
#    1263             return server.run_operation(
# -> 1264                 sock_info, operation, read_preference, self._event_listeners, unpack_res
#    1265             )
#    1266
#
# /usr/local/lib/python3.7/dist-packages/pymongo/server.py in run_operation(self, sock_info, operation, read_preference, listeners, unpack_res)
#     113             else:
#     114                 sock_info.send_message(data, max_doc_size)
# --> 115                 reply = sock_info.receive_message(request_id)
#     116
#     117             # Unpack and check for command errors.
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
# --> 796             self._raise_connection_failure(error)
#     797
#     798     def _raise_if_not_writable(self, unacknowledged):
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     792         """
#     793         try:
# --> 794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
#     796             self._raise_connection_failure(error)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in receive_message(sock_info, request_id, max_message_size)
#     206     # Ignore the response's request id.
#     207     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 208         _receive_data_on_socket(sock_info, 16, deadline)
#     209     )
#     210     # No request_id for exhaust cursor "getMore".
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in _receive_data_on_socket(sock_info, length, deadline)
#     279         try:
#     280             wait_for_read(sock_info, deadline)
# --> 281             chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     282         except (IOError, OSError) as exc:  # noqa: B014
#     283             if _errno_from_exception(exc) == errno.EINTR:
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# UserChapterRole Stream pass

# %%
def stringTransform(stringName):
  try:
    data = str((change['fullDocument'][stringName]))
    data = data.replace("'", "")
    data = data.replace('"', '')
    data = "".join(("'",data,"'"))
  except KeyError:
    data = "NULL"  
  except Exception as e:
    print(e + " e exception")
  return data

db = client[client.list_database_names()[0]]
collection = db['userchapterroles']
change_stream = collection.watch()
conn = psycopg2.connect(database=url.path[1:], user=url.username, password=url.password, host=url.hostname, port=url.port )
cur_esq = conn.cursor()

for change in change_stream:
    if(change['operationType'] == 'insert'):
        insertString = ""

        userChapterRoleID = stringTransform('_id')
        userID = stringTransform('user')
        chapterID = stringTransform('chapter') 
        roleID = stringTransform('role') 
        isCreator = stringTransform('isCreator')
        createdAt = stringTransform('createdAt')
        updatedAt = stringTransform('updatedAt')

        insertString = "".join((insertString,"".join(("(", ",".join((userChapterRoleID, userID, chapterID, roleID, isCreator, createdAt, updatedAt)),")"))))
        cur_esq.execute("".join(("insert into userchapterrole (UserChapterRoleID , userID, ChapterID , RoleID, isCreator, CreateAt, UpdatedAt) values", insertString)))

        conn.commit()
cur_esq.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-4dec39784312> in <module>()
#      17 cur_esq = conn.cursor()
#      18
# ---> 19 for change in change_stream:
#      20     if(change['operationType'] == 'insert'):
#      21         insertString = ""
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in next(self)
#     278         """
#     279         while self.alive:
# --> 280             doc = self.try_next()
#     281             if doc is not None:
#     282                 return doc
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in try_next(self)
#     332         # one resume attempt.
#     333         try:
# --> 334             change = self._cursor._try_next(True)
#     335         except (ConnectionFailure, CursorNotFound):
#     336             self._resume()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _try_next(self, get_more_allowed)
#     293         """Advance the cursor blocking for at most one getMore command."""
#     294         if not len(self.__data) and not self.__killed and get_more_allowed:
# --> 295             self._refresh()
#     296         if len(self.__data):
#     297             return self.__data.popleft()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _refresh(self)
#     227                     self.__sock_mgr,
#     228                     False,
# --> 229                     self.__comment,
#     230                 )
#     231             )
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in __send_message(self, operation)
#     161         try:
#     162             response = client._run_operation(
# --> 163                 operation, self._unpack_response, address=self.__address
#     164             )
#     165         except OperationFailure as exc:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1270             operation.session,
#    1271             address=address,
# -> 1272             retryable=isinstance(operation, message._Query),
#    1273         )
#    1274
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable)
#    1369                         assert last_error is not None
#    1370                         raise last_error
# -> 1371                     return func(session, server, sock_info, read_pref)
#    1372             except ServerSelectionTimeoutError:
#    1373                 if retrying:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _cmd(session, server, sock_info, read_preference)
#    1262         def _cmd(session, server, sock_info, read_preference):
#    1263             return server.run_operation(
# -> 1264                 sock_info, operation, read_preference, self._event_listeners, unpack_res
#    1265             )
#    1266
#
# /usr/local/lib/python3.7/dist-packages/pymongo/server.py in run_operation(self, sock_info, operation, read_preference, listeners, unpack_res)
#     113             else:
#     114                 sock_info.send_message(data, max_doc_size)
# --> 115                 reply = sock_info.receive_message(request_id)
#     116
#     117             # Unpack and check for command errors.
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
# --> 796             self._raise_connection_failure(error)
#     797
#     798     def _raise_if_not_writable(self, unacknowledged):
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     792         """
#     793         try:
# --> 794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
#     796             self._raise_connection_failure(error)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in receive_message(sock_info, request_id, max_message_size)
#     206     # Ignore the response's request id.
#     207     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 208         _receive_data_on_socket(sock_info, 16, deadline)
#     209     )
#     210     # No request_id for exhaust cursor "getMore".
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in _receive_data_on_socket(sock_info, length, deadline)
#     279         try:
#     280             wait_for_read(sock_info, deadline)
# --> 281             chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     282         except (IOError, OSError) as exc:  # noqa: B014
#     283             if _errno_from_exception(exc) == errno.EINTR:
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# TemplateEntry Stream pass

# %%
def stringTransform(stringName):
  try:
    data = str((change['fullDocument'][stringName]))
    data = data.replace("'", "")
    data = data.replace('"', '')
    data = "".join(("'",data,"'"))
  except KeyError:
    data = "NULL"  
  except Exception as e:
    print(e + " e exception")
  return data

db = client[client.list_database_names()[0]]
collection = db['templateentries']
change_stream = collection.watch()
conn = psycopg2.connect(database=url.path[1:], user=url.username, password=url.password, host=url.hostname, port=url.port )
cur_esq = conn.cursor()

for change in change_stream:
    if(change['operationType'] == 'insert'):
        insertString = ""

        templateEntryID = stringTransform('_id')
        creatorID = stringTransform('creator')
        chapterID = stringTransform('chapter') 
        locationID = "NULL" 
        templateType = stringTransform('type')
        createdAt = stringTransform('createdAt')
        updatedAt = stringTransform('updatedAt')

        insertString = "".join((insertString,"".join(("(", ",".join((templateEntryID, creatorID, chapterID, locationID, templateType, createdAt, updatedAt)),")"))))
        cur_esq.execute("".join(("insert into templateEntries (templateEntryID, creatorID, chapterID, locationID, templateType, createdAt, updatedAt)values", insertString)))

        conn.commit()
cur_esq.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-e37e924eec32> in <module>()
#      17 cur_esq = conn.cursor()
#      18
# ---> 19 for change in change_stream:
#      20     if(change['operationType'] == 'insert'):
#      21         insertString = ""
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in next(self)
#     278         """
#     279         while self.alive:
# --> 280             doc = self.try_next()
#     281             if doc is not None:
#     282                 return doc
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in try_next(self)
#     332         # one resume attempt.
#     333         try:
# --> 334             change = self._cursor._try_next(True)
#     335         except (ConnectionFailure, CursorNotFound):
#     336             self._resume()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _try_next(self, get_more_allowed)
#     293         """Advance the cursor blocking for at most one getMore command."""
#     294         if not len(self.__data) and not self.__killed and get_more_allowed:
# --> 295             self._refresh()
#     296         if len(self.__data):
#     297             return self.__data.popleft()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _refresh(self)
#     227                     self.__sock_mgr,
#     228                     False,
# --> 229                     self.__comment,
#     230                 )
#     231             )
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in __send_message(self, operation)
#     161         try:
#     162             response = client._run_operation(
# --> 163                 operation, self._unpack_response, address=self.__address
#     164             )
#     165         except OperationFailure as exc:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1270             operation.session,
#    1271             address=address,
# -> 1272             retryable=isinstance(operation, message._Query),
#    1273         )
#    1274
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable)
#    1369                         assert last_error is not None
#    1370                         raise last_error
# -> 1371                     return func(session, server, sock_info, read_pref)
#    1372             except ServerSelectionTimeoutError:
#    1373                 if retrying:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _cmd(session, server, sock_info, read_preference)
#    1262         def _cmd(session, server, sock_info, read_preference):
#    1263             return server.run_operation(
# -> 1264                 sock_info, operation, read_preference, self._event_listeners, unpack_res
#    1265             )
#    1266
#
# /usr/local/lib/python3.7/dist-packages/pymongo/server.py in run_operation(self, sock_info, operation, read_preference, listeners, unpack_res)
#     113             else:
#     114                 sock_info.send_message(data, max_doc_size)
# --> 115                 reply = sock_info.receive_message(request_id)
#     116
#     117             # Unpack and check for command errors.
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
# --> 796             self._raise_connection_failure(error)
#     797
#     798     def _raise_if_not_writable(self, unacknowledged):
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     792         """
#     793         try:
# --> 794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
#     796             self._raise_connection_failure(error)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in receive_message(sock_info, request_id, max_message_size)
#     206     # Ignore the response's request id.
#     207     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 208         _receive_data_on_socket(sock_info, 16, deadline)
#     209     )
#     210     # No request_id for exhaust cursor "getMore".
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in _receive_data_on_socket(sock_info, length, deadline)
#     279         try:
#     280             wait_for_read(sock_info, deadline)
# --> 281             chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     282         except (IOError, OSError) as exc:  # noqa: B014
#     283             if _errno_from_exception(exc) == errno.EINTR:
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# PromptEntries Stream pass

# %%
def stringTransform(stringName):
  try:
    data = str((change['fullDocument'][stringName]))
    data = data.replace("'", "")
    data = data.replace('"', '')
    data = "".join(("'",data,"'"))
  except KeyError:
    data = "NULL"  
  except Exception as e:
    print(e + " e exception")
  return data

db = client[client.list_database_names()[0]]
collection = db['promptentries']
change_stream = collection.watch()
conn = psycopg2.connect(database=url.path[1:], user=url.username, password=url.password, host=url.hostname, port=url.port )
cur_esq = conn.cursor()

for change in change_stream:
    if(change['operationType'] == 'insert'):
        insertString = ""

        promptEntryID = stringTransform('_id')
        creatorID = stringTransform('creator')
        chapterID = stringTransform('chapter') 
        promptName = stringTransform('prompt') 
        createdAt = stringTransform('createdAt')
        updatedAt = stringTransform('updatedAt')

        insertString = "".join((insertString,"".join(("(", ",".join((promptEntryID, creatorID, chapterID, promptName, createdAt, updatedAt)),")"))))
        cur_esq.execute("".join(("insert into promptentries (promptEntryID, creatorID, chapterID, promptname, createdAt, updatedAt)values", insertString)))

        conn.commit()
cur_esq.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-3b4b1edbfa9e> in <module>()
#      17 cur_esq = conn.cursor()
#      18
# ---> 19 for change in change_stream:
#      20     if(change['operationType'] == 'insert'):
#      21         insertString = ""
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in next(self)
#     278         """
#     279         while self.alive:
# --> 280             doc = self.try_next()
#     281             if doc is not None:
#     282                 return doc
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in try_next(self)
#     332         # one resume attempt.
#     333         try:
# --> 334             change = self._cursor._try_next(True)
#     335         except (ConnectionFailure, CursorNotFound):
#     336             self._resume()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _try_next(self, get_more_allowed)
#     293         """Advance the cursor blocking for at most one getMore command."""
#     294         if not len(self.__data) and not self.__killed and get_more_allowed:
# --> 295             self._refresh()
#     296         if len(self.__data):
#     297             return self.__data.popleft()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _refresh(self)
#     227                     self.__sock_mgr,
#     228                     False,
# --> 229                     self.__comment,
#     230                 )
#     231             )
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in __send_message(self, operation)
#     161         try:
#     162             response = client._run_operation(
# --> 163                 operation, self._unpack_response, address=self.__address
#     164             )
#     165         except OperationFailure as exc:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1270             operation.session,
#    1271             address=address,
# -> 1272             retryable=isinstance(operation, message._Query),
#    1273         )
#    1274
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable)
#    1369                         assert last_error is not None
#    1370                         raise last_error
# -> 1371                     return func(session, server, sock_info, read_pref)
#    1372             except ServerSelectionTimeoutError:
#    1373                 if retrying:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _cmd(session, server, sock_info, read_preference)
#    1262         def _cmd(session, server, sock_info, read_preference):
#    1263             return server.run_operation(
# -> 1264                 sock_info, operation, read_preference, self._event_listeners, unpack_res
#    1265             )
#    1266
#
# /usr/local/lib/python3.7/dist-packages/pymongo/server.py in run_operation(self, sock_info, operation, read_preference, listeners, unpack_res)
#     113             else:
#     114                 sock_info.send_message(data, max_doc_size)
# --> 115                 reply = sock_info.receive_message(request_id)
#     116
#     117             # Unpack and check for command errors.
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
# --> 796             self._raise_connection_failure(error)
#     797
#     798     def _raise_if_not_writable(self, unacknowledged):
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     792         """
#     793         try:
# --> 794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
#     796             self._raise_connection_failure(error)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in receive_message(sock_info, request_id, max_message_size)
#     206     # Ignore the response's request id.
#     207     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 208         _receive_data_on_socket(sock_info, 16, deadline)
#     209     )
#     210     # No request_id for exhaust cursor "getMore".
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in _receive_data_on_socket(sock_info, length, deadline)
#     279         try:
#     280             wait_for_read(sock_info, deadline)
# --> 281             chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     282         except (IOError, OSError) as exc:  # noqa: B014
#     283             if _errno_from_exception(exc) == errno.EINTR:
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# Gallery Entries Stream pass

# %%
def stringTransform(stringName):
  try:
    data = str((change['fullDocument'][stringName]))
    data = data.replace("'", "")
    data = data.replace('"', '')
    data = "".join(("'",data,"'"))
  except KeyError:
    data = "NULL"  
  except Exception as e:
    print(e + " e exception")
  return data

db = client[client.list_database_names()[0]]
collection = db['galleryentries']
change_stream = collection.watch()
conn = psycopg2.connect(database=url.path[1:], user=url.username, password=url.password, host=url.hostname, port=url.port )
cur_esq = conn.cursor()

for change in change_stream:
    if(change['operationType'] == 'insert'):
        insertString = ""

        galleryEntryID = stringTransform('_id')
        creatorID = stringTransform('creator')
        chapterID = stringTransform('chapter') 
        createdAt = stringTransform('createdAt')
        updatedAt = stringTransform('updatedAt')

        insertString = "".join((insertString,"".join(("(", ",".join((galleryEntryID, creatorID, chapterID, createdAt, updatedAt)),")"))))
        cur_esq.execute("".join(("insert into galleryentries (galleryentryid , creatorID, chapterID , CreatedAt , UpdatedAt)values", insertString)))

        conn.commit()
cur_esq.close()
conn.close()

# %% [markdown]
# PhotoEntry Stream pass

# %%
def stringTransform(stringName):
  try:
    data = str((change['fullDocument'][stringName]))
    data = data.replace("'", "")
    data = data.replace('"', '')
    data = "".join(("'",data,"'"))
  except KeyError:
    data = "NULL"  
  except Exception as e:
    print(e + " e exception")
  return data

db = client[client.list_database_names()[0]]
collection = db['photoentries']
change_stream = collection.watch()
conn = psycopg2.connect(database=url.path[1:], user=url.username, password=url.password, host=url.hostname, port=url.port )
cur_esq = conn.cursor()

for change in change_stream:
    if(change['operationType'] == 'insert'):
        insertString = ""

        entryID = stringTransform('_id')
        creatorID = stringTransform('creator')
        chapterID = stringTransform('chapter') 
        galaryEntryID = stringTransform('gallery') 
        url = stringTransform('url')
        createdAt = stringTransform('createdAt')
        updatedAt = stringTransform('updatedAt')

        insertString = "".join((insertString,"".join(("(", ",".join((entryID, creatorID, chapterID, galaryEntryID, url, createdAt, updatedAt)),")"))))
        cur_esq.execute("".join(("insert into photoentries (entryID , creatorID, chapterID, galaryEntryID, url, CreatedAt , UpdatedAt) values", insertString)))

        conn.commit()
cur_esq.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-5efee04ad136> in <module>()
#      17 cur_esq = conn.cursor()
#      18
# ---> 19 for change in change_stream:
#      20     if(change['operationType'] == 'insert'):
#      21         insertString = ""
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in next(self)
#     278         """
#     279         while self.alive:
# --> 280             doc = self.try_next()
#     281             if doc is not None:
#     282                 return doc
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in try_next(self)
#     332         # one resume attempt.
#     333         try:
# --> 334             change = self._cursor._try_next(True)
#     335         except (ConnectionFailure, CursorNotFound):
#     336             self._resume()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _try_next(self, get_more_allowed)
#     293         """Advance the cursor blocking for at most one getMore command."""
#     294         if not len(self.__data) and not self.__killed and get_more_allowed:
# --> 295             self._refresh()
#     296         if len(self.__data):
#     297             return self.__data.popleft()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _refresh(self)
#     227                     self.__sock_mgr,
#     228                     False,
# --> 229                     self.__comment,
#     230                 )
#     231             )
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in __send_message(self, operation)
#     161         try:
#     162             response = client._run_operation(
# --> 163                 operation, self._unpack_response, address=self.__address
#     164             )
#     165         except OperationFailure as exc:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1270             operation.session,
#    1271             address=address,
# -> 1272             retryable=isinstance(operation, message._Query),
#    1273         )
#    1274
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable)
#    1369                         assert last_error is not None
#    1370                         raise last_error
# -> 1371                     return func(session, server, sock_info, read_pref)
#    1372             except ServerSelectionTimeoutError:
#    1373                 if retrying:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _cmd(session, server, sock_info, read_preference)
#    1262         def _cmd(session, server, sock_info, read_preference):
#    1263             return server.run_operation(
# -> 1264                 sock_info, operation, read_preference, self._event_listeners, unpack_res
#    1265             )
#    1266
#
# /usr/local/lib/python3.7/dist-packages/pymongo/server.py in run_operation(self, sock_info, operation, read_preference, listeners, unpack_res)
#     113             else:
#     114                 sock_info.send_message(data, max_doc_size)
# --> 115                 reply = sock_info.receive_message(request_id)
#     116
#     117             # Unpack and check for command errors.
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
# --> 796             self._raise_connection_failure(error)
#     797
#     798     def _raise_if_not_writable(self, unacknowledged):
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     792         """
#     793         try:
# --> 794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
#     796             self._raise_connection_failure(error)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in receive_message(sock_info, request_id, max_message_size)
#     206     # Ignore the response's request id.
#     207     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 208         _receive_data_on_socket(sock_info, 16, deadline)
#     209     )
#     210     # No request_id for exhaust cursor "getMore".
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in _receive_data_on_socket(sock_info, length, deadline)
#     279         try:
#     280             wait_for_read(sock_info, deadline)
# --> 281             chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     282         except (IOError, OSError) as exc:  # noqa: B014
#     283             if _errno_from_exception(exc) == errno.EINTR:
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# Text Entry Stream pass

# %%
def stringTransform(stringName):
  try:
    data = str((change['fullDocument'][stringName]))
    data = data.replace("'", "")
    data = data.replace('"', '')
    data = "".join(("'",data,"'"))
  except KeyError:
    data = "NULL"  
  except Exception as e:
    print(e + " e exception")
  return data

db = client[client.list_database_names()[0]]
collection = db['textentries']
change_stream = collection.watch()
conn = psycopg2.connect(database=url.path[1:], user=url.username, password=url.password, host=url.hostname, port=url.port )
cur_esq = conn.cursor()

for change in change_stream:
    if(change['operationType'] == 'insert'):
        insertString = ""

        textEntryID = stringTransform('_id')
        creatorID = stringTransform('creator')
        chapterID = stringTransform('chapter') 
        locationID = 'NULL'
        entryName = stringTransform('name')
        text = stringTransform('text')
        createdAt = stringTransform('createdAt')
        updatedAt = stringTransform('updatedAt')

        insertString = "".join((insertString,"".join(("(", ",".join((textEntryID, creatorID, chapterID, entryName, text, createdAt, updatedAt)),")"))))
        cur_esq.execute("".join(("insert into textEntries (TextEntryID , creatorID, chapterid ,EntryName, Text , CreatedAt , UpdatedAt)values", insertString)))

        conn.commit()
cur_esq.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-fc97afb0e89c> in <module>()
#      17 cur_esq = conn.cursor()
#      18
# ---> 19 for change in change_stream:
#      20     if(change['operationType'] == 'insert'):
#      21         insertString = ""
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in next(self)
#     278         """
#     279         while self.alive:
# --> 280             doc = self.try_next()
#     281             if doc is not None:
#     282                 return doc
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in try_next(self)
#     332         # one resume attempt.
#     333         try:
# --> 334             change = self._cursor._try_next(True)
#     335         except (ConnectionFailure, CursorNotFound):
#     336             self._resume()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _try_next(self, get_more_allowed)
#     293         """Advance the cursor blocking for at most one getMore command."""
#     294         if not len(self.__data) and not self.__killed and get_more_allowed:
# --> 295             self._refresh()
#     296         if len(self.__data):
#     297             return self.__data.popleft()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _refresh(self)
#     227                     self.__sock_mgr,
#     228                     False,
# --> 229                     self.__comment,
#     230                 )
#     231             )
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in __send_message(self, operation)
#     161         try:
#     162             response = client._run_operation(
# --> 163                 operation, self._unpack_response, address=self.__address
#     164             )
#     165         except OperationFailure as exc:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1270             operation.session,
#    1271             address=address,
# -> 1272             retryable=isinstance(operation, message._Query),
#    1273         )
#    1274
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable)
#    1369                         assert last_error is not None
#    1370                         raise last_error
# -> 1371                     return func(session, server, sock_info, read_pref)
#    1372             except ServerSelectionTimeoutError:
#    1373                 if retrying:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _cmd(session, server, sock_info, read_preference)
#    1262         def _cmd(session, server, sock_info, read_preference):
#    1263             return server.run_operation(
# -> 1264                 sock_info, operation, read_preference, self._event_listeners, unpack_res
#    1265             )
#    1266
#
# /usr/local/lib/python3.7/dist-packages/pymongo/server.py in run_operation(self, sock_info, operation, read_preference, listeners, unpack_res)
#     113             else:
#     114                 sock_info.send_message(data, max_doc_size)
# --> 115                 reply = sock_info.receive_message(request_id)
#     116
#     117             # Unpack and check for command errors.
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
# --> 796             self._raise_connection_failure(error)
#     797
#     798     def _raise_if_not_writable(self, unacknowledged):
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     792         """
#     793         try:
# --> 794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
#     796             self._raise_connection_failure(error)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in receive_message(sock_info, request_id, max_message_size)
#     206     # Ignore the response's request id.
#     207     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 208         _receive_data_on_socket(sock_info, 16, deadline)
#     209     )
#     210     # No request_id for exhaust cursor "getMore".
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in _receive_data_on_socket(sock_info, length, deadline)
#     279         try:
#     280             wait_for_read(sock_info, deadline)
# --> 281             chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     282         except (IOError, OSError) as exc:  # noqa: B014
#     283             if _errno_from_exception(exc) == errno.EINTR:
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# Comment Stream pass

# %%
def stringTransform(stringName):
  try:
    data = str((change['fullDocument'][stringName]))
    data = data.replace("'", "")
    data = data.replace('"', '')
    data = "".join(("'",data,"'"))
  except KeyError:
    data = "NULL"  
  except Exception as e:
    print(e + " e exception")
  return data

db = client[client.list_database_names()[0]]
collection = db['comments']
change_stream = collection.watch()
conn = psycopg2.connect(database=url.path[1:], user=url.username, password=url.password, host=url.hostname, port=url.port )
cur_esq = conn.cursor()

for change in change_stream:
    if(change['operationType'] == 'insert'):
        insertString = ""

        CommentID = stringTransform('_id')
        entryID = stringTransform('entryId')
        chapterID = stringTransform('chapter') 
        authorID = stringTransform('author') 
        entryName = stringTransform('type')
        text = stringTransform('text')
        createdAt = stringTransform('createdAt')
        updatedAt = stringTransform('updatedAt')

        insertString = "".join((insertString,"".join(("(", ",".join((CommentID, entryID, chapterID, authorID, entryName, text, createdAt, updatedAt)),")"))))
        cur_esq.execute("".join(("insert into comment (CommentID, entryID, chapterID, authorID, entryName, text, createdAt, updatedAt) values", insertString)))

        conn.commit()
cur_esq.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-27e4dffd9546> in <module>()
#      17 cur_esq = conn.cursor()
#      18
# ---> 19 for change in change_stream:
#      20     if(change['operationType'] == 'insert'):
#      21         insertString = ""
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in next(self)
#     278         """
#     279         while self.alive:
# --> 280             doc = self.try_next()
#     281             if doc is not None:
#     282                 return doc
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in try_next(self)
#     332         # one resume attempt.
#     333         try:
# --> 334             change = self._cursor._try_next(True)
#     335         except (ConnectionFailure, CursorNotFound):
#     336             self._resume()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _try_next(self, get_more_allowed)
#     293         """Advance the cursor blocking for at most one getMore command."""
#     294         if not len(self.__data) and not self.__killed and get_more_allowed:
# --> 295             self._refresh()
#     296         if len(self.__data):
#     297             return self.__data.popleft()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _refresh(self)
#     227                     self.__sock_mgr,
#     228                     False,
# --> 229                     self.__comment,
#     230                 )
#     231             )
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in __send_message(self, operation)
#     161         try:
#     162             response = client._run_operation(
# --> 163                 operation, self._unpack_response, address=self.__address
#     164             )
#     165         except OperationFailure as exc:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1270             operation.session,
#    1271             address=address,
# -> 1272             retryable=isinstance(operation, message._Query),
#    1273         )
#    1274
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable)
#    1369                         assert last_error is not None
#    1370                         raise last_error
# -> 1371                     return func(session, server, sock_info, read_pref)
#    1372             except ServerSelectionTimeoutError:
#    1373                 if retrying:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _cmd(session, server, sock_info, read_preference)
#    1262         def _cmd(session, server, sock_info, read_preference):
#    1263             return server.run_operation(
# -> 1264                 sock_info, operation, read_preference, self._event_listeners, unpack_res
#    1265             )
#    1266
#
# /usr/local/lib/python3.7/dist-packages/pymongo/server.py in run_operation(self, sock_info, operation, read_preference, listeners, unpack_res)
#     113             else:
#     114                 sock_info.send_message(data, max_doc_size)
# --> 115                 reply = sock_info.receive_message(request_id)
#     116
#     117             # Unpack and check for command errors.
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
# --> 796             self._raise_connection_failure(error)
#     797
#     798     def _raise_if_not_writable(self, unacknowledged):
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     792         """
#     793         try:
# --> 794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
#     796             self._raise_connection_failure(error)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in receive_message(sock_info, request_id, max_message_size)
#     206     # Ignore the response's request id.
#     207     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 208         _receive_data_on_socket(sock_info, 16, deadline)
#     209     )
#     210     # No request_id for exhaust cursor "getMore".
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in _receive_data_on_socket(sock_info, length, deadline)
#     279         try:
#     280             wait_for_read(sock_info, deadline)
# --> 281             chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     282         except (IOError, OSError) as exc:  # noqa: B014
#     283             if _errno_from_exception(exc) == errno.EINTR:
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# User Circle Role Stream pass

# %%
def stringTransform(stringName):
  try:
    data = str((change['fullDocument'][stringName]))
    data = data.replace("'", "")
    data = data.replace('"', '')
    data = "".join(("'",data,"'"))
  except KeyError:
    data = "NULL"  
  except Exception as e:
    print(e + " e exception")
  return data

db = client[client.list_database_names()[0]]
collection = db['usercircleroles']
change_stream = collection.watch()
conn = psycopg2.connect(database=url.path[1:], user=url.username, password=url.password, host=url.hostname, port=url.port )
cur_esq = conn.cursor()

for change in change_stream:
    if(change['operationType'] == 'insert'):
        insertString = ""

        UserCircleRoleID = stringTransform('_id')
        UserID = stringTransform('user')
        CircleID = stringTransform('circle') 
        RoleID = stringTransform('role') 
        createdAt = stringTransform('createdAt')
        updatedAt = stringTransform('updatedAt')

        insertString = "".join((insertString,"".join(("(", ",".join((UserCircleRoleID, UserID, CircleID, RoleID, createdAt, updatedAt)),")"))))
        cur_esq.execute("".join(("insert into userCircleRole (UserCircleRoleID, UserID, CircleID, RoleID, createAt, updatedAt) values", insertString)))

        conn.commit()
cur_esq.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3bf9d52b874b> in <module>()
#      17 cur_esq = conn.cursor()
#      18
# ---> 19 for change in change_stream:
#      20     if(change['operationType'] == 'insert'):
#      21         insertString = ""
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in next(self)
#     278         """
#     279         while self.alive:
# --> 280             doc = self.try_next()
#     281             if doc is not None:
#     282                 return doc
#
# /usr/local/lib/python3.7/dist-packages/pymongo/change_stream.py in try_next(self)
#     332         # one resume attempt.
#     333         try:
# --> 334             change = self._cursor._try_next(True)
#     335         except (ConnectionFailure, CursorNotFound):
#     336             self._resume()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _try_next(self, get_more_allowed)
#     293         """Advance the cursor blocking for at most one getMore command."""
#     294         if not len(self.__data) and not self.__killed and get_more_allowed:
# --> 295             self._refresh()
#     296         if len(self.__data):
#     297             return self.__data.popleft()
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in _refresh(self)
#     227                     self.__sock_mgr,
#     228                     False,
# --> 229                     self.__comment,
#     230                 )
#     231             )
#
# /usr/local/lib/python3.7/dist-packages/pymongo/command_cursor.py in __send_message(self, operation)
#     161         try:
#     162             response = client._run_operation(
# --> 163                 operation, self._unpack_response, address=self.__address
#     164             )
#     165         except OperationFailure as exc:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1270             operation.session,
#    1271             address=address,
# -> 1272             retryable=isinstance(operation, message._Query),
#    1273         )
#    1274
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable)
#    1369                         assert last_error is not None
#    1370                         raise last_error
# -> 1371                     return func(session, server, sock_info, read_pref)
#    1372             except ServerSelectionTimeoutError:
#    1373                 if retrying:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _cmd(session, server, sock_info, read_preference)
#    1262         def _cmd(session, server, sock_info, read_preference):
#    1263             return server.run_operation(
# -> 1264                 sock_info, operation, read_preference, self._event_listeners, unpack_res
#    1265             )
#    1266
#
# /usr/local/lib/python3.7/dist-packages/pymongo/server.py in run_operation(self, sock_info, operation, read_preference, listeners, unpack_res)
#     113             else:
#     114                 sock_info.send_message(data, max_doc_size)
# --> 115                 reply = sock_info.receive_message(request_id)
#     116
#     117             # Unpack and check for command errors.
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
# --> 796             self._raise_connection_failure(error)
#     797
#     798     def _raise_if_not_writable(self, unacknowledged):
#
# /usr/local/lib/python3.7/dist-packages/pymongo/pool.py in receive_message(self, request_id)
#     792         """
#     793         try:
# --> 794             return receive_message(self, request_id, self.max_message_size)
#     795         except BaseException as error:
#     796             self._raise_connection_failure(error)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in receive_message(sock_info, request_id, max_message_size)
#     206     # Ignore the response's request id.
#     207     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 208         _receive_data_on_socket(sock_info, 16, deadline)
#     209     )
#     210     # No request_id for exhaust cursor "getMore".
#
# /usr/local/lib/python3.7/dist-packages/pymongo/network.py in _receive_data_on_socket(sock_info, length, deadline)
#     279         try:
#     280             wait_for_read(sock_info, deadline)
# --> 281             chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     282         except (IOError, OSError) as exc:  # noqa: B014
#     283             if _errno_from_exception(exc) == errno.EINTR:
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
